# %%
import tensorflow as tf
from tensorflow.compat.v1.estimator.experimental import KMeans
from tensorflow.python.framework import ops
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from openpyxl import load_workbook

# %%
# Cluster 개수 설정
k = 3
num_features = 3 # 데이터 Feature 2 (카테고리 분류 코드, 제목)

# 데이터 파일명
filename = 'perfumes.xlsx' 

# 엑셀의 수식이 아닌 셀 값만 받아오도록 data_only = True 로 설정
load_xl = load_workbook(filename, data_only=True)

# train과 test 엑셀 시트 지정
train_sheet = load_xl['kmeans_train']
test_sheet = load_xl['kmeans_test']

# 몇번째 행,열을 가져올지 지정
x_train = train_sheet['A2':'O1112']
x_test = test_sheet['A2':'O40']

# 가져온 데이터를 리스트로 생성
x_train = [[x_train[i][j].value for j in range(len(x_train[i]))] for i in range(len(x_train))]
x_test = [[x_test[i][j].value for j in range(len(x_test[i]))] for i in range(len(x_test))]

# %%
print(x_train, "\n")
print(x_test)
# Out:
# [['Woody Chypre', 'Castoreum', 'Oakmoss', 'Rose', 1, 1, 'long lasting', 'heavy', 4.18, 2113, 'Antaeus', 'Chanel', 0, 3, 0], ['Aromatic Fougere', 'Sandalwood', 'Lavender', 'Mandarin Orange', 1, 2, 'long lasting', 'heavy', 4.19, 30, 'Bois Noir', 'Chanel', 0, 0, 0], ['Floral Woody Musk', 'Orris Root', 'Musk', 'Ylang-Ylang', 2, 1, 'long lasting', 'enormous', 3.58, 18, 'Chanel No 46', 'Chanel', 1, 3, 3], ['Leather', 'Russian Leather', 'Ylang-Ylang', 'Tobacco', 1, 1, 'long lasting', 'heavy', 4.87, 33, 'Cuir de Russie Parfum', 'Chanel', 2, 0, 0], ['Floral', 'Grapefruit', 'Orange Blossom', 'Jasmine', 0, 0, 'moderate', 'moderate', 3.07, 1588, 'Gabrielle', 'Chanel', 1, 2, 3], ['Floral', 'Jasmine', 'iris', 'Oakmoss', 2, 2, 'long lasting', 'enormous', 1, 2, 'Le 1940 Beige de Chanel', 'Chanel', 1, 2, 3], ['Floral Aldehyde', 'Lily-of-the-Valley', 'Aldehydes', 'Vetiver', 2, 2, 'long lasting', 'heavy', 4, 5, 'Le 1940 Bleu de Chanel', 'Chanel', 1, 2, 3], ['Floral Green', 'Jasmine', 'Green Notes', 'Ci
# ...
