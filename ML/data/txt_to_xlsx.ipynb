# %%
import pandas as pd

# %%
# txt 파일을 읽어 엑셀파일로 생성

txtFileName = 'perfumes.txt'
excelFileName = 'perfumes.xlsx'

# DataFrame 생성
df = pd.DataFrame(pd.read_csv(txtFileName, sep=','))
df.columns = ' '.join(df.columns.values).split() # 열 이름 공백 제거

# 빈 값이 들어있는 행 삭제
df = df.dropna(axis=0)

# 향수 이름, 브랜드, 성별, 상황, 분위기 컬럼 추가
df['Perfume_Name'] = ''
df['Brand'] = ''
df['Gender'] = ''
df['TPO'] = ''
df['Mood'] = ''

# 브랜드별 dataFrame 생성
df_chanel = df[df['Name'].apply(str).str.contains('Chanel')]
df_jomalone = df[df['Name'].apply(str).str.contains('Jo Malone')]
df_givenchy = df[df['Name'].apply(str).str.contains('Givenchy')]
df_byredo = df[df['Name'].apply(str).str.contains('Byredo')]
df_anna = df[df['Name'].apply(str).str.contains('Anna Sui')]
df_lelabo = df[df['Name'].apply(str).str.contains('Le Labo')]
df_hermes = df[df['Name'].apply(str).str.contains('Hermès')]
df_lanvin = df[df['Name'].apply(str).str.contains('Lanvin')]
df_ck = df[df['Name'].apply(str).str.contains('Calvin Klein')]
df_bvlgari = df[df['Name'].apply(str).str.contains('Bvlgari')]
df_gucci = df[df['Name'].apply(str).str.contains('Gucci')]
df_diptyque = df[df['Name'].apply(str).str.contains('Diptyque')]
df_dolce = df[df['Name'].apply(str).str.contains('Dolce&Gabbana')]

# Name 열을 추출하는 동시에 제거
name_chanel = df_chanel.pop("Name")
name_jomalone = df_jomalone.pop("Name")
name_givenchy = df_givenchy.pop("Name")
name_byredo = df_byredo.pop("Name")
name_anna = df_anna.pop("Name")
name_lelabo = df_lelabo.pop("Name")
name_hermes = df_hermes.pop("Name")
name_lanvin = df_lanvin.pop("Name")
name_ck = df_ck.pop("Name")
name_bvlgari = df_bvlgari.pop("Name")
name_gucci = df_gucci.pop("Name")
name_diptyque = df_diptyque.pop("Name")
name_dolce = df_dolce.pop("Name")

# %%
# df_chanel
df_jomalone
# df_givenchy
# df_byredo
# df_anna
# df_lelabo
# df_hermes
# df_lanvin
# df_ck
# df_bvlgari
# df_gucci
# df_diptyque
# df_dolce
# Out:
#                  Group    MainNote1    MainNote2    MainNote3         Season  \
# 5072    Woody Aromatic      Vetiver       Nutmeg     Lavender     All Season
# 5073  Oriental Fougere     Lavender        Amber    Patchouli     All Season
# 5074      Floral Green       Neroli        Basil   White Musk  Spring/Summer
# 5075       Woody Spicy       Coffee      vetyver       Nutmeg    Fall/Winter
# 5076     Floral Fruity   Blackberry   Grapefruit     Bay Leaf  Spring/Summer
# ...                ...          ...          ...          ...            ...
# 5178    Aromatic Green       Carrot       Fennel  Violet Root  Spring/Summer
# 5179    Aromatic Green     Lavender    Coriander         Sage    Fall/Winter
# 5180    Aromatic Green    Nasturcia       Clover     Bergamot  Spring/Summer
# 5181    Aromatic Green        Lemon   Petitgrain        Rumex  Spring/Summer
# 5182    Aromatic Green  Green Notes  Tomato Leaf      Parsley  Spring/Summer
#
# ...

# %%
# 원래 txt에는 향수 이름이 (향수이름 + 브랜드 + 성별)로 되어 있으므로 문자열 파싱
df_chanel[['Perfume_Name','Brand','Gender']] = name_chanel.apply(str).str.partition(sep=' Chanel for ')
df_jomalone[['Perfume_Name','Brand','Gender']] = name_jomalone.apply(str).str.partition(sep=' Jo Malone London for ')
df_givenchy[['Perfume_Name','Brand','Gender']] = name_givenchy.apply(str).str.partition(sep=' Givenchy for ')
df_byredo[['Perfume_Name','Brand','Gender']] = name_byredo.apply(str).str.partition(sep=' Byredo for ')
df_anna[['Perfume_Name','Brand','Gender']] = name_anna.apply(str).str.partition(sep=' Anna Sui for ')
df_lelabo[['Perfume_Name','Brand','Gender']] = name_lelabo.apply(str).str.partition(sep=' Le Labo for ')
df_hermes[['Perfume_Name','Brand','Gender']] = name_hermes.apply(str).str.partition(sep=' Hermès for ')
df_lanvin[['Perfume_Name','Brand','Gender']] = name_lanvin.apply(str).str.partition(sep=' Lanvin for ')
df_ck[['Perfume_Name','Brand','Gender']] = name_ck.apply(str).str.partition(sep=' Calvin Klein for ')
df_bvlgari[['Perfume_Name','Brand','Gender']] = name_bvlgari.apply(str).str.partition(sep=' Bvlgari for ')
df_gucci[['Perfume_Name','Brand','Gender']] = name_gucci.apply(str).str.partition(sep=' Gucci for ')
df_diptyque[['Perfume_Name','Brand','Gender']] = name_diptyque.apply(str).str.partition(sep=' Diptyque for ')
df_dolce[['Perfume_Name','Brand','Gender']] = name_dolce.apply(str).str.partition(sep=' Dolce&Gabbana for ')

# 브랜드(Brand) 값 변경
df_chanel['Brand'] = 'Chanel'
df_jomalone['Brand'] = 'Jo Malone London'
df_givenchy['Brand'] = 'Givenchy'
df_byredo['Brand'] = 'Byredo'
df_anna['Brand'] = 'Anna sui'
df_lelabo['Brand'] = 'Le Labo'
df_hermes['Brand'] = 'Hermes'
df_lanvin['Brand'] = 'Lanvin'
df_ck['Brand'] = 'Calvin Klein'
df_bvlgari['Brand'] = 'Bvlgari'
df_gucci['Brand'] = 'Gucci'
df_diptyque['Brand'] = 'Diptyque'
df_dolce['Brand'] = 'Dolce&Gabbana'
# Out:
# C:\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\김다은\AppData\Local\Temp/ipykernel_20852/454915652.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chanel['Brand'] = 'Chanel'
# C:\Users\김다은\AppData\Local\Temp/ipykernel_20852/454915652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# 성별(Gender) 값을 숫자로 변경 : 남성(0), 여성(1), 공용(2)
df_chanel.loc[df_chanel.Gender=='men', 'Gender'] = 0
df_chanel.loc[df_chanel.Gender=='women', 'Gender'] = 1
df_chanel.loc[df_chanel.Gender=='women and men', 'Gender'] = 2

df_jomalone.loc[df_jomalone.Gender=='men', 'Gender'] = 0
df_jomalone.loc[df_jomalone.Gender=='women', 'Gender'] = 1
df_jomalone.loc[df_jomalone.Gender=='women and men', 'Gender'] = 2

df_givenchy.loc[df_givenchy.Gender=='men', 'Gender'] = 0
df_givenchy.loc[df_givenchy.Gender=='women', 'Gender'] = 1
df_givenchy.loc[df_givenchy.Gender=='women and men', 'Gender'] = 2

df_byredo.loc[df_byredo.Gender=='men', 'Gender'] = 0
df_byredo.loc[df_byredo.Gender=='women', 'Gender'] = 1
df_byredo.loc[df_byredo.Gender=='women and men', 'Gender'] = 2

df_anna.loc[df_anna.Gender=='men', 'Gender'] = 0
df_anna.loc[df_anna.Gender=='women', 'Gender'] = 1
df_anna.loc[df_anna.Gender=='women and men', 'Gender'] = 2

df_lelabo.loc[df_lelabo.Gender=='men', 'Gender'] = 0
df_lelabo.loc[df_lelabo.Gender=='women', 'Gender'] = 1
df_lelabo.loc[df_lelabo.Gender=='women and men', 'Gender'] = 2

df_hermes.loc[df_hermes.Gender=='men', 'Gender'] = 0
df_hermes.loc[df_hermes.Gender=='women', 'Gender'] = 1
df_hermes.loc[df_hermes.Gender=='women and men', 'Gender'] = 2

df_lanvin.loc[df_lanvin.Gender=='men', 'Gender'] = 0
df_lanvin.loc[df_lanvin.Gender=='women', 'Gender'] = 1
df_lanvin.loc[df_lanvin.Gender=='women and men', 'Gender'] = 2

df_ck.loc[df_ck.Gender=='men', 'Gender'] = 0
df_ck.loc[df_ck.Gender=='women', 'Gender'] = 1
df_ck.loc[df_ck.Gender=='women and men', 'Gender'] = 2

df_bvlgari.loc[df_bvlgari.Gender=='men', 'Gender'] = 0
df_bvlgari.loc[df_bvlgari.Gender=='women', 'Gender'] = 1
df_bvlgari.loc[df_bvlgari.Gender=='women and men', 'Gender'] = 2

df_gucci.loc[df_gucci.Gender=='men', 'Gender'] = 0
df_gucci.loc[df_gucci.Gender=='women', 'Gender'] = 1
df_gucci.loc[df_gucci.Gender=='women and men', 'Gender'] = 2

df_diptyque.loc[df_diptyque.Gender=='men', 'Gender'] = 0
df_diptyque.loc[df_diptyque.Gender=='women', 'Gender'] = 1
df_diptyque.loc[df_diptyque.Gender=='women and men', 'Gender'] = 2

df_dolce.loc[df_dolce.Gender=='men', 'Gender'] = 0
df_dolce.loc[df_dolce.Gender=='women', 'Gender'] = 1
df_dolce.loc[df_dolce.Gender=='women and men', 'Gender'] = 2
# Out:
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# 상황(TPO) 값을 숫자로 변경 : default(0), 데일리용(1), 데이트용(2), 면접용(3)
df_chanel['TPO'] = 0
df_chanel.loc[df_chanel.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_chanel.loc[df_chanel.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_chanel.loc[df_chanel.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_chanel.loc[df_chanel.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_jomalone['TPO'] = 0
df_jomalone.loc[df_jomalone.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_jomalone.loc[df_jomalone.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_jomalone.loc[df_jomalone.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_jomalone.loc[df_jomalone.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_givenchy['TPO'] = 0
df_givenchy.loc[df_givenchy.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_givenchy.loc[df_givenchy.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_givenchy.loc[df_givenchy.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_givenchy.loc[df_givenchy.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_byredo['TPO'] = 0
df_byredo.loc[df_byredo.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_byredo.loc[df_byredo.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_byredo.loc[df_byredo.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_byredo.loc[df_byredo.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_anna['TPO'] = 0
df_anna.loc[df_anna.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_anna.loc[df_anna.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_anna.loc[df_anna.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_anna.loc[df_anna.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_lelabo['TPO'] = 0
df_lelabo.loc[df_lelabo.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_lelabo.loc[df_lelabo.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_lelabo.loc[df_lelabo.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_lelabo.loc[df_lelabo.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_hermes['TPO'] = 0
df_hermes.loc[df_hermes.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_hermes.loc[df_hermes.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_hermes.loc[df_hermes.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_hermes.loc[df_hermes.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_lanvin['TPO'] = 0
df_lanvin.loc[df_lanvin.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_lanvin.loc[df_lanvin.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_lanvin.loc[df_lanvin.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_lanvin.loc[df_lanvin.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_ck['TPO'] = 0
df_ck.loc[df_ck.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_ck.loc[df_ck.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_ck.loc[df_ck.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_ck.loc[df_ck.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_bvlgari['TPO'] = 0
df_bvlgari.loc[df_bvlgari.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_bvlgari.loc[df_bvlgari.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_bvlgari.loc[df_bvlgari.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_bvlgari.loc[df_bvlgari.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_gucci['TPO'] = 0
df_gucci.loc[df_gucci.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_gucci.loc[df_gucci.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_gucci.loc[df_gucci.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_gucci.loc[df_gucci.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_diptyque['TPO'] = 0
df_diptyque.loc[df_diptyque.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_diptyque.loc[df_diptyque.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_diptyque.loc[df_diptyque.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_diptyque.loc[df_diptyque.Group.apply(str).str.contains('Woody'), 'TPO'] = 3

df_dolce['TPO'] = 0
df_dolce.loc[df_dolce.Group.apply(str).str.contains('Citrus'), 'TPO'] = 1
df_dolce.loc[df_dolce.Group.apply(str).str.contains('Green'), 'TPO'] = 1
df_dolce.loc[df_dolce.Group.apply(str).str.contains('Floral'), 'TPO'] = 2
df_dolce.loc[df_dolce.Group.apply(str).str.contains('Woody'), 'TPO'] = 3
# Out:
# C:\Users\김다은\AppData\Local\Temp/ipykernel_20852/953083327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chanel['TPO'] = 0
# C:\Users\김다은\AppData\Local\Temp/ipykernel_20852/953083327.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jomalone['TPO'] = 0
# C:\Users\김다은\AppData\Local\Temp/ipykernel_20852/953083327.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# 분위기(Mood) 값을 숫자로 변경 : default(0), 상큼한(1), 우아한(2), 상쾌한(3), 따뜻한(4)
df_chanel['Mood'] = 0
df_chanel.loc[df_chanel.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_chanel.loc[df_chanel.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_chanel.loc[df_chanel.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_jomalone['Mood'] = 0
df_jomalone.loc[df_jomalone.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_jomalone.loc[df_jomalone.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_jomalone.loc[df_jomalone.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_givenchy['Mood'] = 0
df_givenchy.loc[df_givenchy.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_givenchy.loc[df_givenchy.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_givenchy.loc[df_givenchy.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_byredo['Mood'] = 0
df_byredo.loc[df_byredo.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_byredo.loc[df_byredo.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_byredo.loc[df_byredo.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_anna['Mood'] = 0
df_anna.loc[df_anna.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_anna.loc[df_anna.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_anna.loc[df_anna.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_lelabo['Mood'] = 0
df_lelabo.loc[df_lelabo.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_lelabo.loc[df_lelabo.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_lelabo.loc[df_lelabo.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_hermes['Mood'] = 0
df_hermes.loc[df_hermes.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_hermes.loc[df_hermes.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_hermes.loc[df_hermes.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_lanvin['Mood'] = 0
df_lanvin.loc[df_lanvin.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_lanvin.loc[df_lanvin.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_lanvin.loc[df_lanvin.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_ck['Mood'] = 0
df_ck.loc[df_ck.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_ck.loc[df_ck.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_ck.loc[df_ck.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_bvlgari['Mood'] = 0
df_bvlgari.loc[df_bvlgari.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_bvlgari.loc[df_bvlgari.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_bvlgari.loc[df_bvlgari.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_gucci['Mood'] = 0
df_gucci.loc[df_gucci.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_gucci.loc[df_gucci.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_gucci.loc[df_gucci.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_diptyque['Mood'] = 0
df_diptyque.loc[df_diptyque.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_diptyque.loc[df_diptyque.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_diptyque.loc[df_diptyque.Group.apply(str).str.contains('Floral'), 'Mood'] = 3

df_dolce['Mood'] = 0
df_dolce.loc[df_dolce.Group.apply(str).str.contains('Citrus'), 'Mood'] = 1
df_dolce.loc[df_dolce.Group.apply(str).str.contains('Green'), 'Mood'] = 2
df_dolce.loc[df_dolce.Group.apply(str).str.contains('Floral'), 'Mood'] = 3
# Out:
# C:\Users\김다은\AppData\Local\Temp/ipykernel_20852/2135237980.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chanel['Mood'] = 0
# C:\Users\김다은\AppData\Local\Temp/ipykernel_20852/2135237980.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jomalone['Mood'] = 0
# C:\Users\김다은\AppData\Local\Temp/ipykernel_20852/2135237980.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# 계절(Season) 값을 숫자로 변경 : 봄/여름(0), 가을/겨울(1), 모든 계절(2)
df_chanel.loc[df_chanel.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_chanel.loc[df_chanel.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_chanel.loc[df_chanel.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_chanel.loc[df_chanel.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_chanel.loc[df_chanel.Season=='All Season', 'Season'] = 2

df_jomalone.loc[df_jomalone.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_jomalone.loc[df_jomalone.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_jomalone.loc[df_jomalone.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_jomalone.loc[df_jomalone.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_jomalone.loc[df_jomalone.Season=='All Season', 'Season'] = 2

df_givenchy.loc[df_givenchy.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_givenchy.loc[df_givenchy.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_givenchy.loc[df_givenchy.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_givenchy.loc[df_givenchy.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_givenchy.loc[df_givenchy.Season=='All Season', 'Season'] = 2

df_byredo.loc[df_byredo.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_byredo.loc[df_byredo.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_byredo.loc[df_byredo.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_byredo.loc[df_byredo.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_byredo.loc[df_byredo.Season=='All Season', 'Season'] = 2

df_anna.loc[df_anna.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_anna.loc[df_anna.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_anna.loc[df_anna.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_anna.loc[df_anna.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_anna.loc[df_anna.Season=='All Season', 'Season'] = 2

df_lelabo.loc[df_lelabo.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_lelabo.loc[df_lelabo.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_lelabo.loc[df_lelabo.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_lelabo.loc[df_lelabo.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_lelabo.loc[df_lelabo.Season=='All Season', 'Season'] = 2

df_hermes.loc[df_hermes.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_hermes.loc[df_hermes.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_hermes.loc[df_hermes.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_hermes.loc[df_hermes.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_hermes.loc[df_hermes.Season=='All Season', 'Season'] = 2

df_lanvin.loc[df_lanvin.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_lanvin.loc[df_lanvin.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_lanvin.loc[df_lanvin.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_lanvin.loc[df_lanvin.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_lanvin.loc[df_lanvin.Season=='All Season', 'Season'] = 2

df_ck.loc[df_ck.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_ck.loc[df_ck.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_ck.loc[df_ck.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_ck.loc[df_ck.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_ck.loc[df_ck.Season=='All Season', 'Season'] = 2

df_bvlgari.loc[df_bvlgari.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_bvlgari.loc[df_bvlgari.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_bvlgari.loc[df_bvlgari.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_bvlgari.loc[df_bvlgari.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_bvlgari.loc[df_bvlgari.Season=='All Season', 'Season'] = 2

df_gucci.loc[df_gucci.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_gucci.loc[df_gucci.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_gucci.loc[df_gucci.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_gucci.loc[df_gucci.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_gucci.loc[df_gucci.Season=='All Season', 'Season'] = 2

df_diptyque.loc[df_diptyque.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_diptyque.loc[df_diptyque.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_diptyque.loc[df_diptyque.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_diptyque.loc[df_diptyque.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_diptyque.loc[df_diptyque.Season=='All Season', 'Season'] = 2

df_dolce.loc[df_dolce.Season.apply(str).apply(str).str.contains('Spring'), 'Season'] = 0
df_dolce.loc[df_dolce.Season.apply(str).apply(str).str.contains('Summer'), 'Season'] = 0
df_dolce.loc[df_dolce.Season.apply(str).apply(str).str.contains('Fall'), 'Season'] = 1
df_dolce.loc[df_dolce.Season.apply(str).apply(str).str.contains('Winter'), 'Season'] = 1
df_dolce.loc[df_dolce.Season=='All Season', 'Season'] = 2

# %%
# 낮/밤(Time) 값을 숫자로 변경 : 낮(0), 밤(1), All Time(2)
df_chanel.loc[df_chanel.Time=='Day', 'Time'] = 0
df_chanel.loc[df_chanel.Time=='Night', 'Time'] = 1
df_chanel.loc[df_chanel.Time=='All Time', 'Time'] = 2

df_jomalone.loc[df_jomalone.Time=='Day', 'Time'] = 0
df_jomalone.loc[df_jomalone.Time=='Night', 'Time'] = 1
df_jomalone.loc[df_jomalone.Time=='All Time', 'Time'] = 2

df_givenchy.loc[df_givenchy.Time=='Day', 'Time'] = 0
df_givenchy.loc[df_givenchy.Time=='Night', 'Time'] = 1
df_givenchy.loc[df_givenchy.Time=='All Time', 'Time'] = 2

df_byredo.loc[df_byredo.Time=='Day', 'Time'] = 0
df_byredo.loc[df_byredo.Time=='Night', 'Time'] = 1
df_byredo.loc[df_byredo.Time=='All Time', 'Time'] = 2

df_anna.loc[df_anna.Time=='Day', 'Time'] = 0
df_anna.loc[df_anna.Time=='Night', 'Time'] = 1
df_anna.loc[df_anna.Time=='All Time', 'Time'] = 2

df_lelabo.loc[df_lelabo.Time=='Day', 'Time'] = 0
df_lelabo.loc[df_lelabo.Time=='Night', 'Time'] = 1
df_lelabo.loc[df_lelabo.Time=='All Time', 'Time'] = 2

df_hermes.loc[df_hermes.Time=='Day', 'Time'] = 0
df_hermes.loc[df_hermes.Time=='Night', 'Time'] = 1
df_hermes.loc[df_hermes.Time=='All Time', 'Time'] = 2

df_lanvin.loc[df_lanvin.Time=='Day', 'Time'] = 0
df_lanvin.loc[df_lanvin.Time=='Night', 'Time'] = 1
df_lanvin.loc[df_lanvin.Time=='All Time', 'Time'] = 2

df_ck.loc[df_ck.Time=='Day', 'Time'] = 0
df_ck.loc[df_ck.Time=='Night', 'Time'] = 1
df_ck.loc[df_ck.Time=='All Time', 'Time'] = 2

df_bvlgari.loc[df_bvlgari.Time=='Day', 'Time'] = 0
df_bvlgari.loc[df_bvlgari.Time=='Night', 'Time'] = 1
df_bvlgari.loc[df_bvlgari.Time=='All Time', 'Time'] = 2

df_gucci.loc[df_gucci.Time=='Day', 'Time'] = 0
df_gucci.loc[df_gucci.Time=='Night', 'Time'] = 1
df_gucci.loc[df_gucci.Time=='All Time', 'Time'] = 2

df_diptyque.loc[df_diptyque.Time=='Day', 'Time'] = 0
df_diptyque.loc[df_diptyque.Time=='Night', 'Time'] = 1
df_diptyque.loc[df_diptyque.Time=='All Time', 'Time'] = 2

df_dolce.loc[df_dolce.Time=='Day', 'Time'] = 0
df_dolce.loc[df_dolce.Time=='Night', 'Time'] = 1
df_dolce.loc[df_dolce.Time=='All Time', 'Time'] = 2

# %%
# data frame 합치기
df = pd.concat([df_chanel, df_jomalone, df_givenchy, df_byredo, df_anna, df_lelabo,
               df_hermes, df_lanvin, df_ck, df_bvlgari, df_gucci, df_diptyque,
               df_dolce])

df

df.to_excel(excelFileName, index=False)
